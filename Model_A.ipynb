# %% [markdown]
# # Model A: Excludes Demographics

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from df_after_transform import df_after_transform
from sklearn import set_config
from sklearn.calibration import CalibrationDisplay
from sklearn.compose import (
    ColumnTransformer,
    make_column_selector,
    make_column_transformer,
)
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingRegressor, HistGradientBoostingClassifier
from sklearn.feature_selection import (
    RFECV,
    SelectFromModel,
    SelectKBest,
    SequentialFeatureSelector,
    f_classif,
)
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Lasso
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    DetCurveDisplay,
    PrecisionRecallDisplay,
    RocCurveDisplay,
    classification_report,
    make_scorer,
    r2_score
)
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Ridge
from sklearn.model_selection import (
    GridSearchCV,
    KFold,
    cross_validate,
    train_test_split,
)
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    PolynomialFeatures,
    StandardScaler,
)
from sklearn.svm import LinearSVC

set_config(display="diagram")  # display='text' is the default

pd.set_option(
    "display.max_colwidth", 1000, "display.max_rows", 50, "display.max_columns", None
)

import warnings

warnings.filterwarnings("ignore")

# %%
set_config(display="diagram")
pd.set_option('display.max_colwidth', 1000, 'display.max_rows', 50, 'display.max_columns', None) 

mortgage = pd.read_csv('Input/mortgage_train.csv')

# %%
mortgage.drop(columns=["census_tract_number","applicant_ethnicity","co_applicant_ethnicity","applicant_race_1",
                       "applicant_race_2","applicant_race_3","applicant_race_4"], axis = 1, inplace=True)
mortgage.drop(columns=["applicant_race_5","co_applicant_race_1","co_applicant_race_2","co_applicant_race_3",
                       "co_applicant_race_4","co_applicant_race_5","applicant_sex"], axis = 1, inplace=True)
mortgage.drop(columns=['county_code','co_applicant_sex','minority_population'], axis = 1, inplace=True)
mortgage
# Out:
#       as_of_year respondent_id                                  agency_name  \
# 0           2017    75-2921540  Department of Housing and Urban Development
# 1           2017    43-1965151  Department of Housing and Urban Development
# 2           2017    86-0860478  Department of Housing and Urban Development
# 3           2017        451965         Consumer Financial Protection Bureau
# 4           2017    36-4327855  Department of Housing and Urban Development
# ...          ...           ...                                          ...
# 9994        2017        451965         Consumer Financial Protection Bureau
# 9995        2017    7505400005  Department of Housing and Urban Development
# 9996        2017        817824         Consumer Financial Protection Bureau
# 9997        2017        817824         Consumer Financial Protection Bureau
# 9998        2017    47-0912342  Department of Housing and Urban Development
#
#      agency_abbr  agency_code loan_type_name  loan_type  \
# 0            HUD            7   Conventional          1
# 1            HUD            7  VA-guaranteed          3
# 2            HUD            7    FHA-insured          2
# 3           CFPB            9    FHA-insured          2
# 4            HUD            7   Conventional          1
# ...          ...          ...            ...        ...
# 9994        CFPB            9   Conventional          1
# 9995         HUD            7    FHA-insured          2
# 9996        CFPB            9   Conventional          1
# 9997        CFPB            9   Conventional          1
# 9998         HUD            7   Conventional          1
#
#                                                  property_type_name  \
# 0     One-to-four family dwelling (other than manufactured housing)
# 1     One-to-four family dwelling (other than manufactured housing)
# 2     One-to-four family dwelling (other than manufactured housing)
# 3     One-to-four family dwelling (other than manufactured housing)
# 4     One-to-four family dwelling (other than manufactured housing)
# ...                                                             ...
# 9994  One-to-four family dwelling (other than manufactured housing)
# 9995  One-to-four family dwelling (other than manufactured housing)
# 9996  One-to-four family dwelling (other than manufactured housing)
# 9997  One-to-four family dwelling (other than manufactured housing)
# 9998  One-to-four family dwelling (other than manufactured housing)
#
#       property_type loan_purpose_name  loan_purpose  \
# 0                 1       Refinancing             3
# 1                 1       Refinancing             3
# 2                 1     Home purchase             1
# 3                 1     Home purchase             1
# 4                 1     Home purchase             1
# ...             ...               ...           ...
# 9994              1     Home purchase             1
# 9995              1       Refinancing             3
# 9996              1       Refinancing             3
# 9997              1  Home improvement             2
# 9998              1       Refinancing             3
#
#                         owner_occupancy_name  owner_occupancy  \
# 0     Owner-occupied as a principal dwelling                1
# 1     Owner-occupied as a principal dwelling                1
# 2     Owner-occupied as a principal dwelling                1
# 3     Owner-occupied as a principal dwelling                1
# 4     Owner-occupied as a principal dwelling                1
# ...                                      ...              ...
# 9994  Owner-occupied as a principal dwelling                1
# 9995  Owner-occupied as a principal dwelling                1
# 9996  Owner-occupied as a principal dwelling                1
# 9997  Owner-occupied as a principal dwelling                1
# 9998  Owner-occupied as a principal dwelling                1
#
#       loan_amount_000s               preapproval_name  preapproval  \
# 0                   53                 Not applicable            3
# 1                  107                 Not applicable            3
# 2                   60                 Not applicable            3
# 3                  196                 Not applicable            3
# 4                  416  Preapproval was not requested            2
# ...                ...                            ...          ...
# 9994               294                 Not applicable            3
# 9995               143                 Not applicable            3
# 9996               105                 Not applicable            3
# 9997                35                 Not applicable            3
# 9998               178                 Not applicable            3
#
#                                 action_taken_name  action_taken  \
# 0              Application withdrawn by applicant             4
# 1     Application denied by financial institution             3
# 2              Application withdrawn by applicant             4
# 3                                 Loan originated             1
# 4                                 Loan originated             1
# ...                                           ...           ...
# 9994  Application denied by financial institution             3
# 9995                              Loan originated             1
# 9996  Application denied by financial institution             3
# 9997  Application denied by financial institution             3
# 9998           Application withdrawn by applicant             4
#
#                                                 msamd_name    msamd  \
# 0                                        Philadelphia - PA  37964.0
# 1                    Scranton, Wilkes-Barre, Hazleton - PA  42540.0
# 2                                        Philadelphia - PA  37964.0
# 3     Montgomery County, Bucks County, Chester County - PA  33874.0
# 4                                        Philadelphia - PA  37964.0
# ...                                                    ...      ...
# 9994                 Allentown, Bethlehem, Easton - PA, NJ  10900.0
# 9995                                    York, Hanover - PA  49620.0
# 9996                                       Pittsburgh - PA  38300.0
# 9997                                 East Stroudsburg - PA  20700.0
# 9998                                                   NaN      NaN
#
#         state_name state_abbr  state_code          county_name  \
# 0     Pennsylvania         PA          42  Philadelphia County
# 1     Pennsylvania         PA          42       Luzerne County
# 2     Pennsylvania         PA          42  Philadelphia County
# 3     Pennsylvania         PA          42    Montgomery County
# 4     Pennsylvania         PA          42  Philadelphia County
# ...            ...        ...         ...                  ...
# 9994  Pennsylvania         PA          42   Northampton County
# 9995  Pennsylvania         PA          42          York County
# 9996  Pennsylvania         PA          42  Westmoreland County
# 9997  Pennsylvania         PA          42        Monroe County
# 9998  Pennsylvania         PA          42   Susquehanna County
#
#                                                                applicant_ethnicity_name  \
# 0                                                                Not Hispanic or Latino
# 1                                                                Not Hispanic or Latino
# 2                                                                Not Hispanic or Latino
# 3                                                                Not Hispanic or Latino
# 4                                                                Not Hispanic or Latino
# ...                                                                                 ...
# 9994                                                             Not Hispanic or Latino
# 9995                                                             Not Hispanic or Latino
# 9996                                                             Not Hispanic or Latino
# 9997                                                             Not Hispanic or Latino
# 9998  Information not provided by applicant in mail, Internet, or telephone application
#
#                                                             co_applicant_ethnicity_name  \
# 0                                                                       No co-applicant
# 1                                                                       No co-applicant
# 2                                                                       No co-applicant
# 3                                                                       No co-applicant
# 4     Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                 ...
# 9994                                                                 Hispanic or Latino
# 9995                                                                    No co-applicant
# 9996                                                                    No co-applicant
# 9997                                                                    No co-applicant
# 9998                                                                    No co-applicant
#
#                                                                   applicant_race_name_1  \
# 0                                                             Black or African American
# 1                                                                                 White
# 2                                                             Black or African American
# 3                                                                                 White
# 4                                                                                 White
# ...                                                                                 ...
# 9994                                                                              White
# 9995                                                                              White
# 9996                                                          Black or African American
# 9997                                                                              White
# 9998  Information not provided by applicant in mail, Internet, or telephone application
#
#      applicant_race_name_2 applicant_race_name_3 applicant_race_name_4  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 9994                   NaN                   NaN                   NaN
# 9995                   NaN                   NaN                   NaN
# 9996                 White                   NaN                   NaN
# 9997                   NaN                   NaN                   NaN
# 9998                   NaN                   NaN                   NaN
#
#      applicant_race_name_5  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 9994                   NaN
# 9995                   NaN
# 9996                   NaN
# 9997                   NaN
# 9998                   NaN
#
#                                                                co_applicant_race_name_1  \
# 0                                                                       No co-applicant
# 1                                                                       No co-applicant
# 2                                                                       No co-applicant
# 3                                                                       No co-applicant
# 4     Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                 ...
# 9994                                                                              White
# 9995                                                                    No co-applicant
# 9996                                                                    No co-applicant
# 9997                                                                    No co-applicant
# 9998                                                                    No co-applicant
#
#      co_applicant_race_name_2 co_applicant_race_name_3  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ...                       ...                      ...
# 9994                      NaN                      NaN
# 9995                      NaN                      NaN
# 9996                      NaN                      NaN
# 9997                      NaN                      NaN
# 9998                      NaN                      NaN
#
#       co_applicant_race_name_4  co_applicant_race_name_5 applicant_sex_name  \
# 0                          NaN                       NaN               Male
# 1                          NaN                       NaN               Male
# 2                          NaN                       NaN             Female
# 3                          NaN                       NaN               Male
# 4                          NaN                       NaN             Female
# ...                        ...                       ...                ...
# 9994                       NaN                       NaN               Male
# 9995                       NaN                       NaN               Male
# 9996                       NaN                       NaN             Female
# 9997                       NaN                       NaN               Male
# 9998                       NaN                       NaN             Female
#
#                                                                   co_applicant_sex_name  \
# 0                                                                       No co-applicant
# 1                                                                       No co-applicant
# 2                                                                       No co-applicant
# 3                                                                       No co-applicant
# 4     Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                 ...
# 9994                                                                             Female
# 9995                                                                    No co-applicant
# 9996                                                                    No co-applicant
# 9997                                                                    No co-applicant
# 9998                                                                    No co-applicant
#
#       applicant_income_000s  \
# 0                      12.0
# 1                      12.0
# 2                      26.0
# 3                      57.0
# 4                     118.0
# ...                     ...
# 9994                   59.0
# 9995                   76.0
# 9996                   37.0
# 9997                   92.0
# 9998                   54.0
#
#                                                                purchaser_type_name  \
# 0     Loan was not originated or was not sold in calendar year covered by register
# 1     Loan was not originated or was not sold in calendar year covered by register
# 2     Loan was not originated or was not sold in calendar year covered by register
# 3                                                                Ginnie Mae (GNMA)
# 4          Life insurance company, credit union, mortgage bank, or finance company
# ...                                                                            ...
# 9994  Loan was not originated or was not sold in calendar year covered by register
# 9995                                                             Ginnie Mae (GNMA)
# 9996  Loan was not originated or was not sold in calendar year covered by register
# 9997  Loan was not originated or was not sold in calendar year covered by register
# 9998  Loan was not originated or was not sold in calendar year covered by register
#
#       purchaser_type  denial_reason_name_1  denial_reason_1  \
# 0                  0                   NaN              NaN
# 1                  0                   NaN              NaN
# 2                  0                   NaN              NaN
# 3                  2                   NaN              NaN
# 4                  7                   NaN              NaN
# ...              ...                   ...              ...
# 9994               0  Debt-to-income ratio              1.0
# 9995               2                   NaN              NaN
# 9996               0        Credit history              3.0
# 9997               0  Debt-to-income ratio              1.0
# 9998               0                   NaN              NaN
#
#      denial_reason_name_2  denial_reason_2 denial_reason_name_3  \
# 0                     NaN              NaN                  NaN
# 1                     NaN              NaN                  NaN
# 2                     NaN              NaN                  NaN
# 3                     NaN              NaN                  NaN
# 4                     NaN              NaN                  NaN
# ...                   ...              ...                  ...
# 9994                  NaN              NaN                  NaN
# 9995                  NaN              NaN                  NaN
# 9996                  NaN              NaN                  NaN
# 9997                  NaN              NaN                  NaN
# 9998                  NaN              NaN                  NaN
#
#       denial_reason_3  rate_spread hoepa_status_name  hoepa_status  \
# 0                 NaN          NaN  Not a HOEPA loan             2
# 1                 NaN          NaN  Not a HOEPA loan             2
# 2                 NaN          NaN  Not a HOEPA loan             2
# 3                 NaN          NaN  Not a HOEPA loan             2
# 4                 NaN          NaN  Not a HOEPA loan             2
# ...               ...          ...               ...           ...
# 9994              NaN          NaN  Not a HOEPA loan             2
# 9995              NaN          NaN  Not a HOEPA loan             2
# 9996              NaN          NaN  Not a HOEPA loan             2
# 9997              NaN          NaN  Not a HOEPA loan             2
# 9998              NaN          NaN  Not a HOEPA loan             2
#
#                    lien_status_name  lien_status  edit_status_name  \
# 0           Secured by a first lien            1               NaN
# 1           Secured by a first lien            1               NaN
# 2           Secured by a first lien            1               NaN
# 3           Secured by a first lien            1               NaN
# 4           Secured by a first lien            1               NaN
# ...                             ...          ...               ...
# 9994        Secured by a first lien            1               NaN
# 9995        Secured by a first lien            1               NaN
# 9996        Secured by a first lien            1               NaN
# 9997  Secured by a subordinate lien            2               NaN
# 9998        Secured by a first lien            1               NaN
#
#       edit_status  sequence_number  population  hud_median_family_income  \
# 0             NaN              NaN      3202.0                   57400.0
# 1             NaN              NaN      3382.0                   59500.0
# 2             NaN              NaN      6385.0                   57400.0
# 3             NaN              NaN      4078.0                  102600.0
# 4             NaN              NaN      6711.0                   57400.0
# ...           ...              ...         ...                       ...
# 9994          NaN              NaN      6455.0                   75200.0
# 9995          NaN              NaN      4093.0                   70800.0
# 9996          NaN              NaN      2321.0                   72200.0
# 9997          NaN              NaN      6185.0                   74900.0
# 9998          NaN              NaN      3937.0                   57500.0
#
#       tract_to_msamd_income  number_of_owner_occupied_units  \
# 0                 47.540001                           710.0
# 1                 93.230003                          1016.0
# 2                101.790001                          1595.0
# 3                 73.889999                          1021.0
# 4                 92.760002                          1702.0
# ...                     ...                             ...
# 9994             137.500000                          2201.0
# 9995             103.540001                          1400.0
# 9996              72.290001                           756.0
# 9997              83.680000                          1802.0
# 9998             115.080002                          1311.0
#
#       number_of_1_to_4_family_units  application_date_indicator
# 0                            1314.0                         NaN
# 1                            1389.0                         NaN
# 2                            2475.0                         NaN
# 3                            1463.0                         NaN
# 4                            3063.0                         NaN
# ...                             ...                         ...
# 9994                         2364.0                         NaN
# 9995                         1579.0                         NaN
# 9996                         1039.0                         NaN
# 9997                         2518.0                         NaN
# 9998                         2207.0                         NaN
#
# [9999 rows x 61 columns]

# %%
perc = 94.6 # Like N %
min_count =  int(((100-perc)/100)*mortgage.shape[0] + 1)
mortgage = mortgage.dropna( axis=1, 
                thresh=min_count)

# %%
mortgage
# Out:
#       as_of_year respondent_id                                  agency_name  \
# 0           2017    75-2921540  Department of Housing and Urban Development
# 1           2017    43-1965151  Department of Housing and Urban Development
# 2           2017    86-0860478  Department of Housing and Urban Development
# 3           2017        451965         Consumer Financial Protection Bureau
# 4           2017    36-4327855  Department of Housing and Urban Development
# ...          ...           ...                                          ...
# 9994        2017        451965         Consumer Financial Protection Bureau
# 9995        2017    7505400005  Department of Housing and Urban Development
# 9996        2017        817824         Consumer Financial Protection Bureau
# 9997        2017        817824         Consumer Financial Protection Bureau
# 9998        2017    47-0912342  Department of Housing and Urban Development
#
#      agency_abbr  agency_code loan_type_name  loan_type  \
# 0            HUD            7   Conventional          1
# 1            HUD            7  VA-guaranteed          3
# 2            HUD            7    FHA-insured          2
# 3           CFPB            9    FHA-insured          2
# 4            HUD            7   Conventional          1
# ...          ...          ...            ...        ...
# 9994        CFPB            9   Conventional          1
# 9995         HUD            7    FHA-insured          2
# 9996        CFPB            9   Conventional          1
# 9997        CFPB            9   Conventional          1
# 9998         HUD            7   Conventional          1
#
#                                                  property_type_name  \
# 0     One-to-four family dwelling (other than manufactured housing)
# 1     One-to-four family dwelling (other than manufactured housing)
# 2     One-to-four family dwelling (other than manufactured housing)
# 3     One-to-four family dwelling (other than manufactured housing)
# 4     One-to-four family dwelling (other than manufactured housing)
# ...                                                             ...
# 9994  One-to-four family dwelling (other than manufactured housing)
# 9995  One-to-four family dwelling (other than manufactured housing)
# 9996  One-to-four family dwelling (other than manufactured housing)
# 9997  One-to-four family dwelling (other than manufactured housing)
# 9998  One-to-four family dwelling (other than manufactured housing)
#
#       property_type loan_purpose_name  loan_purpose  \
# 0                 1       Refinancing             3
# 1                 1       Refinancing             3
# 2                 1     Home purchase             1
# 3                 1     Home purchase             1
# 4                 1     Home purchase             1
# ...             ...               ...           ...
# 9994              1     Home purchase             1
# 9995              1       Refinancing             3
# 9996              1       Refinancing             3
# 9997              1  Home improvement             2
# 9998              1       Refinancing             3
#
#                         owner_occupancy_name  owner_occupancy  \
# 0     Owner-occupied as a principal dwelling                1
# 1     Owner-occupied as a principal dwelling                1
# 2     Owner-occupied as a principal dwelling                1
# 3     Owner-occupied as a principal dwelling                1
# 4     Owner-occupied as a principal dwelling                1
# ...                                      ...              ...
# 9994  Owner-occupied as a principal dwelling                1
# 9995  Owner-occupied as a principal dwelling                1
# 9996  Owner-occupied as a principal dwelling                1
# 9997  Owner-occupied as a principal dwelling                1
# 9998  Owner-occupied as a principal dwelling                1
#
#       loan_amount_000s               preapproval_name  preapproval  \
# 0                   53                 Not applicable            3
# 1                  107                 Not applicable            3
# 2                   60                 Not applicable            3
# 3                  196                 Not applicable            3
# 4                  416  Preapproval was not requested            2
# ...                ...                            ...          ...
# 9994               294                 Not applicable            3
# 9995               143                 Not applicable            3
# 9996               105                 Not applicable            3
# 9997                35                 Not applicable            3
# 9998               178                 Not applicable            3
#
#                                 action_taken_name  action_taken  \
# 0              Application withdrawn by applicant             4
# 1     Application denied by financial institution             3
# 2              Application withdrawn by applicant             4
# 3                                 Loan originated             1
# 4                                 Loan originated             1
# ...                                           ...           ...
# 9994  Application denied by financial institution             3
# 9995                              Loan originated             1
# 9996  Application denied by financial institution             3
# 9997  Application denied by financial institution             3
# 9998           Application withdrawn by applicant             4
#
#                                                 msamd_name    msamd  \
# 0                                        Philadelphia - PA  37964.0
# 1                    Scranton, Wilkes-Barre, Hazleton - PA  42540.0
# 2                                        Philadelphia - PA  37964.0
# 3     Montgomery County, Bucks County, Chester County - PA  33874.0
# 4                                        Philadelphia - PA  37964.0
# ...                                                    ...      ...
# 9994                 Allentown, Bethlehem, Easton - PA, NJ  10900.0
# 9995                                    York, Hanover - PA  49620.0
# 9996                                       Pittsburgh - PA  38300.0
# 9997                                 East Stroudsburg - PA  20700.0
# 9998                                                   NaN      NaN
#
#         state_name state_abbr  state_code          county_name  \
# 0     Pennsylvania         PA          42  Philadelphia County
# 1     Pennsylvania         PA          42       Luzerne County
# 2     Pennsylvania         PA          42  Philadelphia County
# 3     Pennsylvania         PA          42    Montgomery County
# 4     Pennsylvania         PA          42  Philadelphia County
# ...            ...        ...         ...                  ...
# 9994  Pennsylvania         PA          42   Northampton County
# 9995  Pennsylvania         PA          42          York County
# 9996  Pennsylvania         PA          42  Westmoreland County
# 9997  Pennsylvania         PA          42        Monroe County
# 9998  Pennsylvania         PA          42   Susquehanna County
#
#                                                                applicant_ethnicity_name  \
# 0                                                                Not Hispanic or Latino
# 1                                                                Not Hispanic or Latino
# 2                                                                Not Hispanic or Latino
# 3                                                                Not Hispanic or Latino
# 4                                                                Not Hispanic or Latino
# ...                                                                                 ...
# 9994                                                             Not Hispanic or Latino
# 9995                                                             Not Hispanic or Latino
# 9996                                                             Not Hispanic or Latino
# 9997                                                             Not Hispanic or Latino
# 9998  Information not provided by applicant in mail, Internet, or telephone application
#
#                                                             co_applicant_ethnicity_name  \
# 0                                                                       No co-applicant
# 1                                                                       No co-applicant
# 2                                                                       No co-applicant
# 3                                                                       No co-applicant
# 4     Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                 ...
# 9994                                                                 Hispanic or Latino
# 9995                                                                    No co-applicant
# 9996                                                                    No co-applicant
# 9997                                                                    No co-applicant
# 9998                                                                    No co-applicant
#
#                                                                   applicant_race_name_1  \
# 0                                                             Black or African American
# 1                                                                                 White
# 2                                                             Black or African American
# 3                                                                                 White
# 4                                                                                 White
# ...                                                                                 ...
# 9994                                                                              White
# 9995                                                                              White
# 9996                                                          Black or African American
# 9997                                                                              White
# 9998  Information not provided by applicant in mail, Internet, or telephone application
#
#                                                                co_applicant_race_name_1  \
# 0                                                                       No co-applicant
# 1                                                                       No co-applicant
# 2                                                                       No co-applicant
# 3                                                                       No co-applicant
# 4     Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                 ...
# 9994                                                                              White
# 9995                                                                    No co-applicant
# 9996                                                                    No co-applicant
# 9997                                                                    No co-applicant
# 9998                                                                    No co-applicant
#
#      applicant_sex_name  \
# 0                  Male
# 1                  Male
# 2                Female
# 3                  Male
# 4                Female
# ...                 ...
# 9994               Male
# 9995               Male
# 9996             Female
# 9997               Male
# 9998             Female
#
#                                                                   co_applicant_sex_name  \
# 0                                                                       No co-applicant
# 1                                                                       No co-applicant
# 2                                                                       No co-applicant
# 3                                                                       No co-applicant
# 4     Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                 ...
# 9994                                                                             Female
# 9995                                                                    No co-applicant
# 9996                                                                    No co-applicant
# 9997                                                                    No co-applicant
# 9998                                                                    No co-applicant
#
#       applicant_income_000s  \
# 0                      12.0
# 1                      12.0
# 2                      26.0
# 3                      57.0
# 4                     118.0
# ...                     ...
# 9994                   59.0
# 9995                   76.0
# 9996                   37.0
# 9997                   92.0
# 9998                   54.0
#
#                                                                purchaser_type_name  \
# 0     Loan was not originated or was not sold in calendar year covered by register
# 1     Loan was not originated or was not sold in calendar year covered by register
# 2     Loan was not originated or was not sold in calendar year covered by register
# 3                                                                Ginnie Mae (GNMA)
# 4          Life insurance company, credit union, mortgage bank, or finance company
# ...                                                                            ...
# 9994  Loan was not originated or was not sold in calendar year covered by register
# 9995                                                             Ginnie Mae (GNMA)
# 9996  Loan was not originated or was not sold in calendar year covered by register
# 9997  Loan was not originated or was not sold in calendar year covered by register
# 9998  Loan was not originated or was not sold in calendar year covered by register
#
#       purchaser_type  denial_reason_name_1  denial_reason_1 hoepa_status_name  \
# 0                  0                   NaN              NaN  Not a HOEPA loan
# 1                  0                   NaN              NaN  Not a HOEPA loan
# 2                  0                   NaN              NaN  Not a HOEPA loan
# 3                  2                   NaN              NaN  Not a HOEPA loan
# 4                  7                   NaN              NaN  Not a HOEPA loan
# ...              ...                   ...              ...               ...
# 9994               0  Debt-to-income ratio              1.0  Not a HOEPA loan
# 9995               2                   NaN              NaN  Not a HOEPA loan
# 9996               0        Credit history              3.0  Not a HOEPA loan
# 9997               0  Debt-to-income ratio              1.0  Not a HOEPA loan
# 9998               0                   NaN              NaN  Not a HOEPA loan
#
#       hoepa_status               lien_status_name  lien_status  population  \
# 0                2        Secured by a first lien            1      3202.0
# 1                2        Secured by a first lien            1      3382.0
# 2                2        Secured by a first lien            1      6385.0
# 3                2        Secured by a first lien            1      4078.0
# 4                2        Secured by a first lien            1      6711.0
# ...            ...                            ...          ...         ...
# 9994             2        Secured by a first lien            1      6455.0
# 9995             2        Secured by a first lien            1      4093.0
# 9996             2        Secured by a first lien            1      2321.0
# 9997             2  Secured by a subordinate lien            2      6185.0
# 9998             2        Secured by a first lien            1      3937.0
#
#       hud_median_family_income  tract_to_msamd_income  \
# 0                      57400.0              47.540001
# 1                      59500.0              93.230003
# 2                      57400.0             101.790001
# 3                     102600.0              73.889999
# 4                      57400.0              92.760002
# ...                        ...                    ...
# 9994                   75200.0             137.500000
# 9995                   70800.0             103.540001
# 9996                   72200.0              72.290001
# 9997                   74900.0              83.680000
# 9998                   57500.0             115.080002
#
#       number_of_owner_occupied_units  number_of_1_to_4_family_units
# 0                              710.0                         1314.0
# 1                             1016.0                         1389.0
# 2                             1595.0                         2475.0
# 3                             1021.0                         1463.0
# 4                             1702.0                         3063.0
# ...                              ...                            ...
# 9994                          2201.0                         2364.0
# 9995                          1400.0                         1579.0
# 9996                           756.0                         1039.0
# 9997                          1802.0                         2518.0
# 9998                          1311.0                         2207.0
#
# [9999 rows x 44 columns]

# %%
mortgage = mortgage[(mortgage.action_taken == 2) | (mortgage.action_taken == 3)]

# %%
#mortgage[(mortgage.action_taken != 1) & (mortgage.action_taken != 4) & (mortgage.action_taken != 4) & (mortgage.action_taken != 4)]

# %%
#mortgage.info()

# %%
mortgage
# Out:
#       as_of_year respondent_id                                  agency_name  \
# 1           2017    43-1965151  Department of Housing and Urban Development
# 6           2017        480228         Consumer Financial Protection Bureau
# 12          2017        817824         Consumer Financial Protection Bureau
# 14          2017    7197000003  Department of Housing and Urban Development
# 16          2017        675332         Consumer Financial Protection Bureau
# ...          ...           ...                                          ...
# 9985        2017        817824         Consumer Financial Protection Bureau
# 9991        2017         24891    Office of the Comptroller of the Currency
# 9994        2017        451965         Consumer Financial Protection Bureau
# 9996        2017        817824         Consumer Financial Protection Bureau
# 9997        2017        817824         Consumer Financial Protection Bureau
#
#      agency_abbr  agency_code loan_type_name  loan_type  \
# 1            HUD            7  VA-guaranteed          3
# 6           CFPB            9   Conventional          1
# 12          CFPB            9   Conventional          1
# 14           HUD            7    FHA-insured          2
# 16          CFPB            9   Conventional          1
# ...          ...          ...            ...        ...
# 9985        CFPB            9   Conventional          1
# 9991         OCC            1   Conventional          1
# 9994        CFPB            9   Conventional          1
# 9996        CFPB            9   Conventional          1
# 9997        CFPB            9   Conventional          1
#
#                                                  property_type_name  \
# 1     One-to-four family dwelling (other than manufactured housing)
# 6     One-to-four family dwelling (other than manufactured housing)
# 12    One-to-four family dwelling (other than manufactured housing)
# 14    One-to-four family dwelling (other than manufactured housing)
# 16    One-to-four family dwelling (other than manufactured housing)
# ...                                                             ...
# 9985  One-to-four family dwelling (other than manufactured housing)
# 9991  One-to-four family dwelling (other than manufactured housing)
# 9994  One-to-four family dwelling (other than manufactured housing)
# 9996  One-to-four family dwelling (other than manufactured housing)
# 9997  One-to-four family dwelling (other than manufactured housing)
#
#       property_type loan_purpose_name  loan_purpose  \
# 1                 1       Refinancing             3
# 6                 1       Refinancing             3
# 12                1  Home improvement             2
# 14                1       Refinancing             3
# 16                1  Home improvement             2
# ...             ...               ...           ...
# 9985              1       Refinancing             3
# 9991              1       Refinancing             3
# 9994              1     Home purchase             1
# 9996              1       Refinancing             3
# 9997              1  Home improvement             2
#
#                             owner_occupancy_name  owner_occupancy  \
# 1         Owner-occupied as a principal dwelling                1
# 6     Not owner-occupied as a principal dwelling                2
# 12        Owner-occupied as a principal dwelling                1
# 14        Owner-occupied as a principal dwelling                1
# 16    Not owner-occupied as a principal dwelling                2
# ...                                          ...              ...
# 9985      Owner-occupied as a principal dwelling                1
# 9991      Owner-occupied as a principal dwelling                1
# 9994      Owner-occupied as a principal dwelling                1
# 9996      Owner-occupied as a principal dwelling                1
# 9997      Owner-occupied as a principal dwelling                1
#
#       loan_amount_000s preapproval_name  preapproval  \
# 1                  107   Not applicable            3
# 6                   70   Not applicable            3
# 12                  18   Not applicable            3
# 14                 101   Not applicable            3
# 16                   5   Not applicable            3
# ...                ...              ...          ...
# 9985                96   Not applicable            3
# 9991               138   Not applicable            3
# 9994               294   Not applicable            3
# 9996               105   Not applicable            3
# 9997                35   Not applicable            3
#
#                                 action_taken_name  action_taken  \
# 1     Application denied by financial institution             3
# 6     Application denied by financial institution             3
# 12    Application denied by financial institution             3
# 14    Application denied by financial institution             3
# 16    Application denied by financial institution             3
# ...                                           ...           ...
# 9985  Application denied by financial institution             3
# 9991  Application denied by financial institution             3
# 9994  Application denied by financial institution             3
# 9996  Application denied by financial institution             3
# 9997  Application denied by financial institution             3
#
#                                  msamd_name    msamd    state_name state_abbr  \
# 1     Scranton, Wilkes-Barre, Hazleton - PA  42540.0  Pennsylvania         PA
# 6                         Philadelphia - PA  37964.0  Pennsylvania         PA
# 12                          Pittsburgh - PA  38300.0  Pennsylvania         PA
# 14                        Philadelphia - PA  37964.0  Pennsylvania         PA
# 16                        Philadelphia - PA  37964.0  Pennsylvania         PA
# ...                                     ...      ...           ...        ...
# 9985  Allentown, Bethlehem, Easton - PA, NJ  10900.0  Pennsylvania         PA
# 9991                           Lebanon - PA  30140.0  Pennsylvania         PA
# 9994  Allentown, Bethlehem, Easton - PA, NJ  10900.0  Pennsylvania         PA
# 9996                        Pittsburgh - PA  38300.0  Pennsylvania         PA
# 9997                  East Stroudsburg - PA  20700.0  Pennsylvania         PA
#
#       state_code          county_name  \
# 1             42       Luzerne County
# 6             42  Philadelphia County
# 12            42  Westmoreland County
# 14            42  Philadelphia County
# 16            42  Philadelphia County
# ...          ...                  ...
# 9985          42        Lehigh County
# 9991          42       Lebanon County
# 9994          42   Northampton County
# 9996          42  Westmoreland County
# 9997          42        Monroe County
#
#                                                                applicant_ethnicity_name  \
# 1                                                                Not Hispanic or Latino
# 6     Information not provided by applicant in mail, Internet, or telephone application
# 12                                                               Not Hispanic or Latino
# 14                                                               Not Hispanic or Latino
# 16                                                               Not Hispanic or Latino
# ...                                                                                 ...
# 9985                                                             Not Hispanic or Latino
# 9991                                                             Not Hispanic or Latino
# 9994                                                             Not Hispanic or Latino
# 9996                                                             Not Hispanic or Latino
# 9997                                                             Not Hispanic or Latino
#
#      co_applicant_ethnicity_name  \
# 1                No co-applicant
# 6                No co-applicant
# 12        Not Hispanic or Latino
# 14        Not Hispanic or Latino
# 16               No co-applicant
# ...                          ...
# 9985      Not Hispanic or Latino
# 9991      Not Hispanic or Latino
# 9994          Hispanic or Latino
# 9996             No co-applicant
# 9997             No co-applicant
#
#                                                                   applicant_race_name_1  \
# 1                                                                                 White
# 6     Information not provided by applicant in mail, Internet, or telephone application
# 12                                                                                White
# 14                                                            Black or African American
# 16                                                                                White
# ...                                                                                 ...
# 9985                                                                              White
# 9991                                                                              White
# 9994                                                                              White
# 9996                                                          Black or African American
# 9997                                                                              White
#
#        co_applicant_race_name_1  \
# 1               No co-applicant
# 6               No co-applicant
# 12    Black or African American
# 14    Black or African American
# 16              No co-applicant
# ...                         ...
# 9985                      White
# 9991                      White
# 9994                      White
# 9996            No co-applicant
# 9997            No co-applicant
#
#                                                                      applicant_sex_name  \
# 1                                                                                  Male
# 6     Information not provided by applicant in mail, Internet, or telephone application
# 12                                                                               Female
# 14                                                                                 Male
# 16                                                                                 Male
# ...                                                                                 ...
# 9985                                                                             Female
# 9991                                                                               Male
# 9994                                                                               Male
# 9996                                                                             Female
# 9997                                                                               Male
#
#      co_applicant_sex_name  applicant_income_000s  \
# 1          No co-applicant                   12.0
# 6          No co-applicant                   62.0
# 12                  Female                   27.0
# 14                  Female                  100.0
# 16         No co-applicant                   72.0
# ...                    ...                    ...
# 9985                  Male                   46.0
# 9991                Female                   81.0
# 9994                Female                   59.0
# 9996       No co-applicant                   37.0
# 9997       No co-applicant                   92.0
#
#                                                                purchaser_type_name  \
# 1     Loan was not originated or was not sold in calendar year covered by register
# 6     Loan was not originated or was not sold in calendar year covered by register
# 12    Loan was not originated or was not sold in calendar year covered by register
# 14    Loan was not originated or was not sold in calendar year covered by register
# 16    Loan was not originated or was not sold in calendar year covered by register
# ...                                                                            ...
# 9985  Loan was not originated or was not sold in calendar year covered by register
# 9991  Loan was not originated or was not sold in calendar year covered by register
# 9994  Loan was not originated or was not sold in calendar year covered by register
# 9996  Loan was not originated or was not sold in calendar year covered by register
# 9997  Loan was not originated or was not sold in calendar year covered by register
#
#       purchaser_type  denial_reason_name_1  denial_reason_1 hoepa_status_name  \
# 1                  0                   NaN              NaN  Not a HOEPA loan
# 6                  0  Debt-to-income ratio              1.0  Not a HOEPA loan
# 12                 0        Credit history              3.0  Not a HOEPA loan
# 14                 0            Collateral              4.0  Not a HOEPA loan
# 16                 0  Debt-to-income ratio              1.0  Not a HOEPA loan
# ...              ...                   ...              ...               ...
# 9985               0  Debt-to-income ratio              1.0  Not a HOEPA loan
# 9991               0            Collateral              4.0  Not a HOEPA loan
# 9994               0  Debt-to-income ratio              1.0  Not a HOEPA loan
# 9996               0        Credit history              3.0  Not a HOEPA loan
# 9997               0  Debt-to-income ratio              1.0  Not a HOEPA loan
#
#       hoepa_status               lien_status_name  lien_status  population  \
# 1                2        Secured by a first lien            1      3382.0
# 6                2        Secured by a first lien            1      3202.0
# 12               2          Not secured by a lien            3      2986.0
# 14               2        Secured by a first lien            1      6385.0
# 16               2          Not secured by a lien            3      6711.0
# ...            ...                            ...          ...         ...
# 9985             2        Secured by a first lien            1      4831.0
# 9991             2        Secured by a first lien            1      4177.0
# 9994             2        Secured by a first lien            1      6455.0
# 9996             2        Secured by a first lien            1      2321.0
# 9997             2  Secured by a subordinate lien            2      6185.0
#
#       hud_median_family_income  tract_to_msamd_income  \
# 1                      59500.0              93.230003
# 6                      57400.0              47.540001
# 12                     72200.0              81.120003
# 14                     57400.0             101.790001
# 16                     57400.0              92.760002
# ...                        ...                    ...
# 9985                   75200.0             118.480003
# 9991                   65300.0             121.730003
# 9994                   75200.0             137.500000
# 9996                   72200.0              72.290001
# 9997                   74900.0              83.680000
#
#       number_of_owner_occupied_units  number_of_1_to_4_family_units
# 1                             1016.0                         1389.0
# 6                              710.0                         1314.0
# 12                            1049.0                         1446.0
# 14                            1595.0                         2475.0
# 16                            1702.0                         3063.0
# ...                              ...                            ...
# 9985                          1553.0                         1882.0
# 9991                          1346.0                         1771.0
# 9994                          2201.0                         2364.0
# 9996                           756.0                         1039.0
# 9997                          1802.0                         2518.0
#
# [3204 rows x 44 columns]

# %%
#mortgage.loc[mortgage['action_taken'] == 3] # Application approved but not accepted

# %%
y = mortgage.action_taken== 3
y.value_counts()
mortgage = mortgage.drop("action_taken", axis=1)

# stratify will make sure that test/train both have equal fractions of outcome
X_train, X_test, y_train, y_test = train_test_split(mortgage, y, stratify=y, test_size=0.2, random_state=0
)

# %%
numer_pipe = make_pipeline(SimpleImputer(),StandardScaler()) 

cat_pipe = make_pipeline(OneHotEncoder())


preproc_pipe = ColumnTransformer([("num_impute", numer_pipe, make_column_selector(dtype_include=np.number)),
                                  ("cat_trans", cat_pipe, ['loan_purpose_name'])],remainder = 'drop')

clf_logit = make_pipeline(preproc_pipe, LogisticRegression())

# %%
clf_logit.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_impute',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fe1f50405b0>),
#                                                  ('cat_trans',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['loan_purpose_name'])])),
#                 ('logisticregression', LogisticRegression())])

# %% [raw]
# predictions = clf_logit.predict(X_train)
#
# probabilities = clf_logit.predict_proba(X_train)
#
# from sklearn.metrics import r2_score
#
# r2_score(y_train, predictions)

# %%
print(classification_report(y_train, 
                            clf_logit.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.67      0.01      0.01       267
#         True       0.90      1.00      0.95      2296
#
#     accuracy                           0.90      2563
#    macro avg       0.78      0.50      0.48      2563
# weighted avg       0.87      0.90      0.85      2563

# %%
ConfusionMatrixDisplay.from_estimator(clf_logit, X_train, y_train)

# %%
CalibrationDisplay.from_estimator(clf_logit, X_train, y_train)

# %%
logit_pred_test = pd.DataFrame({'Respondent_ID': X_test['respondent_id'], 'Prediction': clf_logit.predict(X_test)})
logit_pred_test
# Out:
#      Respondent_ID  Prediction
# 1488         66158        True
# 3495        705537        True
# 2022    26-4599244        True
# 2532    22-3747694        True
# 4749    1768800000        True
# ...            ...         ...
# 6481        817824        True
# 8576        280110        True
# 9943    47-0912342        True
# 9462    36-4771976        True
# 6912         30011        True
#
# [641 rows x 2 columns]

# %%
logit_pred_test.to_csv('pred/testex1.csv', index=False)

# %%
bigmort = pd.read_csv('Input/mortgage_holdout.csv')

# %%
bigmort.drop(columns=["census_tract_number","applicant_ethnicity","co_applicant_ethnicity","applicant_race_1",
                       "applicant_race_2","applicant_race_3","applicant_race_4"], axis = 1, inplace=True)
bigmort.drop(columns=["applicant_race_5","co_applicant_race_1","co_applicant_race_2","co_applicant_race_3",
                       "co_applicant_race_4","co_applicant_race_5","applicant_sex"], axis = 1, inplace=True)
bigmort.drop(columns=['county_code','co_applicant_sex','minority_population'], axis = 1, inplace=True)
bigmort
# Out:
#         as_of_year respondent_id                                  agency_name  \
# 0             2017    75-2921540  Department of Housing and Urban Development
# 1             2017    43-1965151  Department of Housing and Urban Development
# 2             2017    86-0860478  Department of Housing and Urban Development
# 3             2017    0000451965         Consumer Financial Protection Bureau
# 4             2017    36-4327855  Department of Housing and Urban Development
# ...            ...           ...                                          ...
# 473752        2017    26-2261031  Department of Housing and Urban Development
# 473753        2017    0000013879        Federal Deposit Insurance Corporation
# 473754        2017    45-5510883  Department of Housing and Urban Development
# 473755        2017    0000002551         National Credit Union Administration
# 473756        2017    0000006694         National Credit Union Administration
#
#        agency_abbr  agency_code loan_type_name  loan_type  \
# 0              HUD            7   Conventional          1
# 1              HUD            7  VA-guaranteed          3
# 2              HUD            7    FHA-insured          2
# 3             CFPB            9    FHA-insured          2
# 4              HUD            7   Conventional          1
# ...            ...          ...            ...        ...
# 473752         HUD            7   Conventional          1
# 473753        FDIC            3   Conventional          1
# 473754         HUD            7  VA-guaranteed          3
# 473755        NCUA            5   Conventional          1
# 473756        NCUA            5   Conventional          1
#
#                                                    property_type_name  \
# 0       One-to-four family dwelling (other than manufactured housing)
# 1       One-to-four family dwelling (other than manufactured housing)
# 2       One-to-four family dwelling (other than manufactured housing)
# 3       One-to-four family dwelling (other than manufactured housing)
# 4       One-to-four family dwelling (other than manufactured housing)
# ...                                                               ...
# 473752  One-to-four family dwelling (other than manufactured housing)
# 473753  One-to-four family dwelling (other than manufactured housing)
# 473754  One-to-four family dwelling (other than manufactured housing)
# 473755  One-to-four family dwelling (other than manufactured housing)
# 473756  One-to-four family dwelling (other than manufactured housing)
#
#         property_type loan_purpose_name  loan_purpose  \
# 0                   1       Refinancing             3
# 1                   1       Refinancing             3
# 2                   1     Home purchase             1
# 3                   1     Home purchase             1
# 4                   1     Home purchase             1
# ...               ...               ...           ...
# 473752              1       Refinancing             3
# 473753              1  Home improvement             2
# 473754              1       Refinancing             3
# 473755              1       Refinancing             3
# 473756              1  Home improvement             2
#
#                           owner_occupancy_name  owner_occupancy  \
# 0       Owner-occupied as a principal dwelling                1
# 1       Owner-occupied as a principal dwelling                1
# 2       Owner-occupied as a principal dwelling                1
# 3       Owner-occupied as a principal dwelling                1
# 4       Owner-occupied as a principal dwelling                1
# ...                                        ...              ...
# 473752  Owner-occupied as a principal dwelling                1
# 473753  Owner-occupied as a principal dwelling                1
# 473754  Owner-occupied as a principal dwelling                1
# 473755  Owner-occupied as a principal dwelling                1
# 473756  Owner-occupied as a principal dwelling                1
#
#         loan_amount_000s               preapproval_name  preapproval  \
# 0                     53                 Not applicable            3
# 1                    107                 Not applicable            3
# 2                     60                 Not applicable            3
# 3                    196                 Not applicable            3
# 4                    416  Preapproval was not requested            2
# ...                  ...                            ...          ...
# 473752                53                 Not applicable            3
# 473753                 3                 Not applicable            3
# 473754               155                 Not applicable            3
# 473755                31                 Not applicable            3
# 473756                60                 Not applicable            3
#
#                                   action_taken_name  action_taken  \
# 0                Application withdrawn by applicant             4
# 1       Application denied by financial institution             3
# 2                Application withdrawn by applicant             4
# 3                                   Loan originated             1
# 4                                   Loan originated             1
# ...                                             ...           ...
# 473752        Application approved but not accepted             2
# 473753                              Loan originated             1
# 473754  Application denied by financial institution             3
# 473755  Application denied by financial institution             3
# 473756  Application denied by financial institution             3
#
#                                                   msamd_name    msamd  \
# 0                                          Philadelphia - PA  37964.0
# 1                      Scranton, Wilkes-Barre, Hazleton - PA  42540.0
# 2                                          Philadelphia - PA  37964.0
# 3       Montgomery County, Bucks County, Chester County - PA  33874.0
# 4                                          Philadelphia - PA  37964.0
# ...                                                      ...      ...
# 473752                                     Philadelphia - PA  37964.0
# 473753                                    York, Hanover - PA  49620.0
# 473754                                     Philadelphia - PA  37964.0
# 473755                                     Philadelphia - PA  37964.0
# 473756                                    York, Hanover - PA  49620.0
#
#           state_name state_abbr  state_code          county_name  \
# 0       Pennsylvania         PA          42  Philadelphia County
# 1       Pennsylvania         PA          42       Luzerne County
# 2       Pennsylvania         PA          42  Philadelphia County
# 3       Pennsylvania         PA          42    Montgomery County
# 4       Pennsylvania         PA          42  Philadelphia County
# ...              ...        ...         ...                  ...
# 473752  Pennsylvania         PA          42  Philadelphia County
# 473753  Pennsylvania         PA          42          York County
# 473754  Pennsylvania         PA          42  Philadelphia County
# 473755  Pennsylvania         PA          42  Philadelphia County
# 473756  Pennsylvania         PA          42          York County
#
#                                                                  applicant_ethnicity_name  \
# 0                                                                  Not Hispanic or Latino
# 1                                                                  Not Hispanic or Latino
# 2                                                                  Not Hispanic or Latino
# 3                                                                  Not Hispanic or Latino
# 4                                                                  Not Hispanic or Latino
# ...                                                                                   ...
# 473752                                                             Not Hispanic or Latino
# 473753  Information not provided by applicant in mail, Internet, or telephone application
# 473754                                                                 Hispanic or Latino
# 473755                                                             Not Hispanic or Latino
# 473756                                                             Not Hispanic or Latino
#
#                                                               co_applicant_ethnicity_name  \
# 0                                                                         No co-applicant
# 1                                                                         No co-applicant
# 2                                                                         No co-applicant
# 3                                                                         No co-applicant
# 4       Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                   ...
# 473752                                                                    No co-applicant
# 473753  Information not provided by applicant in mail, Internet, or telephone application
# 473754                                                                    No co-applicant
# 473755                                                             Not Hispanic or Latino
# 473756                                                             Not Hispanic or Latino
#
#             applicant_race_name_1 applicant_race_name_2 applicant_race_name_3  \
# 0       Black or African American                   NaN                   NaN
# 1                           White                   NaN                   NaN
# 2       Black or African American                   NaN                   NaN
# 3                           White                   NaN                   NaN
# 4                           White                   NaN                   NaN
# ...                           ...                   ...                   ...
# 473752  Black or African American                   NaN                   NaN
# 473753                      White                   NaN                   NaN
# 473754                      White                   NaN                   NaN
# 473755  Black or African American                   NaN                   NaN
# 473756                      White                   NaN                   NaN
#
#        applicant_race_name_4 applicant_race_name_5  \
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                        NaN                   NaN
# 3                        NaN                   NaN
# 4                        NaN                   NaN
# ...                      ...                   ...
# 473752                   NaN                   NaN
# 473753                   NaN                   NaN
# 473754                   NaN                   NaN
# 473755                   NaN                   NaN
# 473756                   NaN                   NaN
#
#                                                                  co_applicant_race_name_1  \
# 0                                                                         No co-applicant
# 1                                                                         No co-applicant
# 2                                                                         No co-applicant
# 3                                                                         No co-applicant
# 4       Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                   ...
# 473752                                                                    No co-applicant
# 473753                                                                              White
# 473754                                                                    No co-applicant
# 473755                                                          Black or African American
# 473756                                                                              White
#
#        co_applicant_race_name_2 co_applicant_race_name_3  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 473752                      NaN                      NaN
# 473753                      NaN                      NaN
# 473754                      NaN                      NaN
# 473755                      NaN                      NaN
# 473756                      NaN                      NaN
#
#        co_applicant_race_name_4 co_applicant_race_name_5 applicant_sex_name  \
# 0                           NaN                      NaN               Male
# 1                           NaN                      NaN               Male
# 2                           NaN                      NaN             Female
# 3                           NaN                      NaN               Male
# 4                           NaN                      NaN             Female
# ...                         ...                      ...                ...
# 473752                      NaN                      NaN             Female
# 473753                      NaN                      NaN             Female
# 473754                      NaN                      NaN               Male
# 473755                      NaN                      NaN               Male
# 473756                      NaN                      NaN             Female
#
#                                                                     co_applicant_sex_name  \
# 0                                                                         No co-applicant
# 1                                                                         No co-applicant
# 2                                                                         No co-applicant
# 3                                                                         No co-applicant
# 4       Information not provided by applicant in mail, Internet, or telephone application
# ...                                                                                   ...
# 473752                                                                    No co-applicant
# 473753                                                                               Male
# 473754                                                                    No co-applicant
# 473755                                                                             Female
# 473756                                                                               Male
#
#         applicant_income_000s  \
# 0                        12.0
# 1                        12.0
# 2                        26.0
# 3                        57.0
# 4                       118.0
# ...                       ...
# 473752                   16.0
# 473753                   85.0
# 473754                    NaN
# 473755                   64.0
# 473756                  102.0
#
#                                                                  purchaser_type_name  \
# 0       Loan was not originated or was not sold in calendar year covered by register
# 1       Loan was not originated or was not sold in calendar year covered by register
# 2       Loan was not originated or was not sold in calendar year covered by register
# 3                                                                  Ginnie Mae (GNMA)
# 4            Life insurance company, credit union, mortgage bank, or finance company
# ...                                                                              ...
# 473752  Loan was not originated or was not sold in calendar year covered by register
# 473753  Loan was not originated or was not sold in calendar year covered by register
# 473754  Loan was not originated or was not sold in calendar year covered by register
# 473755  Loan was not originated or was not sold in calendar year covered by register
# 473756  Loan was not originated or was not sold in calendar year covered by register
#
#         purchaser_type denial_reason_name_1  denial_reason_1  \
# 0                    0                  NaN              NaN
# 1                    0                  NaN              NaN
# 2                    0                  NaN              NaN
# 3                    2                  NaN              NaN
# 4                    7                  NaN              NaN
# ...                ...                  ...              ...
# 473752               0                  NaN              NaN
# 473753               0                  NaN              NaN
# 473754               0                Other              9.0
# 473755               0                  NaN              NaN
# 473756               0       Credit history              3.0
#
#        denial_reason_name_2  denial_reason_2 denial_reason_name_3  \
# 0                       NaN              NaN                  NaN
# 1                       NaN              NaN                  NaN
# 2                       NaN              NaN                  NaN
# 3                       NaN              NaN                  NaN
# 4                       NaN              NaN                  NaN
# ...                     ...              ...                  ...
# 473752                  NaN              NaN                  NaN
# 473753                  NaN              NaN                  NaN
# 473754                  NaN              NaN                  NaN
# 473755                  NaN              NaN                  NaN
# 473756                  NaN              NaN                  NaN
#
#         denial_reason_3  rate_spread hoepa_status_name  hoepa_status  \
# 0                   NaN          NaN  Not a HOEPA loan             2
# 1                   NaN          NaN  Not a HOEPA loan             2
# 2                   NaN          NaN  Not a HOEPA loan             2
# 3                   NaN          NaN  Not a HOEPA loan             2
# 4                   NaN          NaN  Not a HOEPA loan             2
# ...                 ...          ...               ...           ...
# 473752              NaN          NaN  Not a HOEPA loan             2
# 473753              NaN          NaN  Not a HOEPA loan             2
# 473754              NaN          NaN  Not a HOEPA loan             2
# 473755              NaN          NaN  Not a HOEPA loan             2
# 473756              NaN          NaN  Not a HOEPA loan             2
#
#                lien_status_name  lien_status  edit_status_name  edit_status  \
# 0       Secured by a first lien            1               NaN          NaN
# 1       Secured by a first lien            1               NaN          NaN
# 2       Secured by a first lien            1               NaN          NaN
# 3       Secured by a first lien            1               NaN          NaN
# 4       Secured by a first lien            1               NaN          NaN
# ...                         ...          ...               ...          ...
# 473752  Secured by a first lien            1               NaN          NaN
# 473753    Not secured by a lien            3               NaN          NaN
# 473754  Secured by a first lien            1               NaN          NaN
# 473755  Secured by a first lien            1               NaN          NaN
# 473756  Secured by a first lien            1               NaN          NaN
#
#         sequence_number  population  hud_median_family_income  \
# 0                   NaN      3202.0                   57400.0
# 1                   NaN      3382.0                   59500.0
# 2                   NaN      6385.0                   57400.0
# 3                   NaN      4078.0                  102600.0
# 4                   NaN      6711.0                   57400.0
# ...                 ...         ...                       ...
# 473752              NaN      4269.0                   57400.0
# 473753              NaN      5130.0                   70800.0
# 473754              NaN      6283.0                   57400.0
# 473755              NaN      4141.0                   57400.0
# 473756              NaN      7523.0                   70800.0
#
#         tract_to_msamd_income  number_of_owner_occupied_units  \
# 0                   47.540001                           710.0
# 1                   93.230003                          1016.0
# 2                  101.790001                          1595.0
# 3                   73.889999                          1021.0
# 4                   92.760002                          1702.0
# ...                       ...                             ...
# 473752              70.129997                          1064.0
# 473753             109.510002                          1550.0
# 473754              97.400002                          1385.0
# 473755              61.540001                           889.0
# 473756             107.750000                          2484.0
#
#         number_of_1_to_4_family_units  application_date_indicator
# 0                              1314.0                         NaN
# 1                              1389.0                         NaN
# 2                              2475.0                         NaN
# 3                              1463.0                         NaN
# 4                              3063.0                         NaN
# ...                               ...                         ...
# 473752                         1771.0                         NaN
# 473753                         1786.0                         NaN
# 473754                         1883.0                         NaN
# 473755                         1655.0                         NaN
# 473756                         3099.0                         NaN
#
# [473757 rows x 61 columns]

# %%
perc = 94.6 # Like N %
min_count =  int(((100-perc)/100)*mortgage.shape[0] + 1)
bigmort = bigmort.dropna( axis=1, 
                thresh=min_count)

# %%
bigmort = bigmort[(bigmort.action_taken == 2) | (bigmort.action_taken == 3)]

# %%
bigmort
# Out:
#         as_of_year respondent_id                                  agency_name  \
# 1             2017    43-1965151  Department of Housing and Urban Development
# 6             2017    0000480228         Consumer Financial Protection Bureau
# 12            2017    0000817824         Consumer Financial Protection Bureau
# 14            2017    7197000003  Department of Housing and Urban Development
# 16            2017    0000675332         Consumer Financial Protection Bureau
# ...            ...           ...                                          ...
# 473749        2017    0000451965         Consumer Financial Protection Bureau
# 473752        2017    26-2261031  Department of Housing and Urban Development
# 473754        2017    45-5510883  Department of Housing and Urban Development
# 473755        2017    0000002551         National Credit Union Administration
# 473756        2017    0000006694         National Credit Union Administration
#
#        agency_abbr  agency_code loan_type_name  loan_type  \
# 1              HUD            7  VA-guaranteed          3
# 6             CFPB            9   Conventional          1
# 12            CFPB            9   Conventional          1
# 14             HUD            7    FHA-insured          2
# 16            CFPB            9   Conventional          1
# ...            ...          ...            ...        ...
# 473749        CFPB            9   Conventional          1
# 473752         HUD            7   Conventional          1
# 473754         HUD            7  VA-guaranteed          3
# 473755        NCUA            5   Conventional          1
# 473756        NCUA            5   Conventional          1
#
#                                                    property_type_name  \
# 1       One-to-four family dwelling (other than manufactured housing)
# 6       One-to-four family dwelling (other than manufactured housing)
# 12      One-to-four family dwelling (other than manufactured housing)
# 14      One-to-four family dwelling (other than manufactured housing)
# 16      One-to-four family dwelling (other than manufactured housing)
# ...                                                               ...
# 473749  One-to-four family dwelling (other than manufactured housing)
# 473752  One-to-four family dwelling (other than manufactured housing)
# 473754  One-to-four family dwelling (other than manufactured housing)
# 473755  One-to-four family dwelling (other than manufactured housing)
# 473756  One-to-four family dwelling (other than manufactured housing)
#
#         property_type loan_purpose_name  loan_purpose  \
# 1                   1       Refinancing             3
# 6                   1       Refinancing             3
# 12                  1  Home improvement             2
# 14                  1       Refinancing             3
# 16                  1  Home improvement             2
# ...               ...               ...           ...
# 473749              1     Home purchase             1
# 473752              1       Refinancing             3
# 473754              1       Refinancing             3
# 473755              1       Refinancing             3
# 473756              1  Home improvement             2
#
#                               owner_occupancy_name  owner_occupancy  \
# 1           Owner-occupied as a principal dwelling                1
# 6       Not owner-occupied as a principal dwelling                2
# 12          Owner-occupied as a principal dwelling                1
# 14          Owner-occupied as a principal dwelling                1
# 16      Not owner-occupied as a principal dwelling                2
# ...                                            ...              ...
# 473749  Not owner-occupied as a principal dwelling                2
# 473752      Owner-occupied as a principal dwelling                1
# 473754      Owner-occupied as a principal dwelling                1
# 473755      Owner-occupied as a principal dwelling                1
# 473756      Owner-occupied as a principal dwelling                1
#
#         loan_amount_000s preapproval_name  preapproval  \
# 1                    107   Not applicable            3
# 6                     70   Not applicable            3
# 12                    18   Not applicable            3
# 14                   101   Not applicable            3
# 16                     5   Not applicable            3
# ...                  ...              ...          ...
# 473749               100   Not applicable            3
# 473752                53   Not applicable            3
# 473754               155   Not applicable            3
# 473755                31   Not applicable            3
# 473756                60   Not applicable            3
#
#                                   action_taken_name  action_taken  \
# 1       Application denied by financial institution             3
# 6       Application denied by financial institution             3
# 12      Application denied by financial institution             3
# 14      Application denied by financial institution             3
# 16      Application denied by financial institution             3
# ...                                             ...           ...
# 473749  Application denied by financial institution             3
# 473752        Application approved but not accepted             2
# 473754  Application denied by financial institution             3
# 473755  Application denied by financial institution             3
# 473756  Application denied by financial institution             3
#
#                                    msamd_name    msamd    state_name  \
# 1       Scranton, Wilkes-Barre, Hazleton - PA  42540.0  Pennsylvania
# 6                           Philadelphia - PA  37964.0  Pennsylvania
# 12                            Pittsburgh - PA  38300.0  Pennsylvania
# 14                          Philadelphia - PA  37964.0  Pennsylvania
# 16                          Philadelphia - PA  37964.0  Pennsylvania
# ...                                       ...      ...           ...
# 473749                        Newark - NJ, PA  35084.0  Pennsylvania
# 473752                      Philadelphia - PA  37964.0  Pennsylvania
# 473754                      Philadelphia - PA  37964.0  Pennsylvania
# 473755                      Philadelphia - PA  37964.0  Pennsylvania
# 473756                     York, Hanover - PA  49620.0  Pennsylvania
#
#        state_abbr  state_code          county_name  \
# 1              PA          42       Luzerne County
# 6              PA          42  Philadelphia County
# 12             PA          42  Westmoreland County
# 14             PA          42  Philadelphia County
# 16             PA          42  Philadelphia County
# ...           ...         ...                  ...
# 473749         PA          42          Pike County
# 473752         PA          42  Philadelphia County
# 473754         PA          42  Philadelphia County
# 473755         PA          42  Philadelphia County
# 473756         PA          42          York County
#
#                                                                  applicant_ethnicity_name  \
# 1                                                                  Not Hispanic or Latino
# 6       Information not provided by applicant in mail, Internet, or telephone application
# 12                                                                 Not Hispanic or Latino
# 14                                                                 Not Hispanic or Latino
# 16                                                                 Not Hispanic or Latino
# ...                                                                                   ...
# 473749                                                             Not Hispanic or Latino
# 473752                                                             Not Hispanic or Latino
# 473754                                                                 Hispanic or Latino
# 473755                                                             Not Hispanic or Latino
# 473756                                                             Not Hispanic or Latino
#
#        co_applicant_ethnicity_name  \
# 1                  No co-applicant
# 6                  No co-applicant
# 12          Not Hispanic or Latino
# 14          Not Hispanic or Latino
# 16                 No co-applicant
# ...                            ...
# 473749          Hispanic or Latino
# 473752             No co-applicant
# 473754             No co-applicant
# 473755      Not Hispanic or Latino
# 473756      Not Hispanic or Latino
#
#                                                                     applicant_race_name_1  \
# 1                                                                                   White
# 6       Information not provided by applicant in mail, Internet, or telephone application
# 12                                                                                  White
# 14                                                              Black or African American
# 16                                                                                  White
# ...                                                                                   ...
# 473749                                                                              White
# 473752                                                          Black or African American
# 473754                                                                              White
# 473755                                                          Black or African American
# 473756                                                                              White
#
#        applicant_race_name_2  \
# 1                        NaN
# 6                        NaN
# 12                       NaN
# 14                       NaN
# 16                       NaN
# ...                      ...
# 473749                   NaN
# 473752                   NaN
# 473754                   NaN
# 473755                   NaN
# 473756                   NaN
#
#                                                                  co_applicant_race_name_1  \
# 1                                                                         No co-applicant
# 6                                                                         No co-applicant
# 12                                                              Black or African American
# 14                                                              Black or African American
# 16                                                                        No co-applicant
# ...                                                                                   ...
# 473749  Information not provided by applicant in mail, Internet, or telephone application
# 473752                                                                    No co-applicant
# 473754                                                                    No co-applicant
# 473755                                                          Black or African American
# 473756                                                                              White
#
#        co_applicant_race_name_2  \
# 1                           NaN
# 6                           NaN
# 12                          NaN
# 14                          NaN
# 16                          NaN
# ...                         ...
# 473749                      NaN
# 473752                      NaN
# 473754                      NaN
# 473755                      NaN
# 473756                      NaN
#
#                                                                        applicant_sex_name  \
# 1                                                                                    Male
# 6       Information not provided by applicant in mail, Internet, or telephone application
# 12                                                                                 Female
# 14                                                                                   Male
# 16                                                                                   Male
# ...                                                                                   ...
# 473749                                                                               Male
# 473752                                                                             Female
# 473754                                                                               Male
# 473755                                                                               Male
# 473756                                                                             Female
#
#        co_applicant_sex_name  applicant_income_000s  \
# 1            No co-applicant                   12.0
# 6            No co-applicant                   62.0
# 12                    Female                   27.0
# 14                    Female                  100.0
# 16           No co-applicant                   72.0
# ...                      ...                    ...
# 473749                Female                   91.0
# 473752       No co-applicant                   16.0
# 473754       No co-applicant                    NaN
# 473755                Female                   64.0
# 473756                  Male                  102.0
#
#                                                                  purchaser_type_name  \
# 1       Loan was not originated or was not sold in calendar year covered by register
# 6       Loan was not originated or was not sold in calendar year covered by register
# 12      Loan was not originated or was not sold in calendar year covered by register
# 14      Loan was not originated or was not sold in calendar year covered by register
# 16      Loan was not originated or was not sold in calendar year covered by register
# ...                                                                              ...
# 473749  Loan was not originated or was not sold in calendar year covered by register
# 473752  Loan was not originated or was not sold in calendar year covered by register
# 473754  Loan was not originated or was not sold in calendar year covered by register
# 473755  Loan was not originated or was not sold in calendar year covered by register
# 473756  Loan was not originated or was not sold in calendar year covered by register
#
#         purchaser_type  denial_reason_name_1  denial_reason_1  \
# 1                    0                   NaN              NaN
# 6                    0  Debt-to-income ratio              1.0
# 12                   0        Credit history              3.0
# 14                   0            Collateral              4.0
# 16                   0  Debt-to-income ratio              1.0
# ...                ...                   ...              ...
# 473749               0  Debt-to-income ratio              1.0
# 473752               0                   NaN              NaN
# 473754               0                 Other              9.0
# 473755               0                   NaN              NaN
# 473756               0        Credit history              3.0
#
#        denial_reason_name_2  denial_reason_2 denial_reason_name_3  \
# 1                       NaN              NaN                  NaN
# 6                       NaN              NaN                  NaN
# 12                      NaN              NaN                  NaN
# 14                      NaN              NaN                  NaN
# 16           Credit history              3.0                  NaN
# ...                     ...              ...                  ...
# 473749                  NaN              NaN                  NaN
# 473752                  NaN              NaN                  NaN
# 473754                  NaN              NaN                  NaN
# 473755                  NaN              NaN                  NaN
# 473756                  NaN              NaN                  NaN
#
#         denial_reason_3  rate_spread hoepa_status_name  hoepa_status  \
# 1                   NaN          NaN  Not a HOEPA loan             2
# 6                   NaN          NaN  Not a HOEPA loan             2
# 12                  NaN          NaN  Not a HOEPA loan             2
# 14                  NaN          NaN  Not a HOEPA loan             2
# 16                  NaN          NaN  Not a HOEPA loan             2
# ...                 ...          ...               ...           ...
# 473749              NaN          NaN  Not a HOEPA loan             2
# 473752              NaN          NaN  Not a HOEPA loan             2
# 473754              NaN          NaN  Not a HOEPA loan             2
# 473755              NaN          NaN  Not a HOEPA loan             2
# 473756              NaN          NaN  Not a HOEPA loan             2
#
#                lien_status_name  lien_status  population  \
# 1       Secured by a first lien            1      3382.0
# 6       Secured by a first lien            1      3202.0
# 12        Not secured by a lien            3      2986.0
# 14      Secured by a first lien            1      6385.0
# 16        Not secured by a lien            3      6711.0
# ...                         ...          ...         ...
# 473749  Secured by a first lien            1      2528.0
# 473752  Secured by a first lien            1      4269.0
# 473754  Secured by a first lien            1      6283.0
# 473755  Secured by a first lien            1      4141.0
# 473756  Secured by a first lien            1      7523.0
#
#         hud_median_family_income  tract_to_msamd_income  \
# 1                        59500.0              93.230003
# 6                        57400.0              47.540001
# 12                       72200.0              81.120003
# 14                       57400.0             101.790001
# 16                       57400.0              92.760002
# ...                          ...                    ...
# 473749                   99800.0              50.869999
# 473752                   57400.0              70.129997
# 473754                   57400.0              97.400002
# 473755                   57400.0              61.540001
# 473756                   70800.0             107.750000
#
#         number_of_owner_occupied_units  number_of_1_to_4_family_units
# 1                               1016.0                         1389.0
# 6                                710.0                         1314.0
# 12                              1049.0                         1446.0
# 14                              1595.0                         2475.0
# 16                              1702.0                         3063.0
# ...                                ...                            ...
# 473749                           986.0                         2332.0
# 473752                          1064.0                         1771.0
# 473754                          1385.0                         1883.0
# 473755                           889.0                         1655.0
# 473756                          2484.0                         3099.0
#
# [88185 rows x 51 columns]

# %%
bigtest = pd.DataFrame({'Respondent_ID': bigmort['respondent_id'], 'Prediction': clf_logit.predict(bigmort)})
bigtest
# Out:
#        Respondent_ID  Prediction
# 1         43-1965151        True
# 6         0000480228        True
# 12        0000817824        True
# 14        7197000003        True
# 16        0000675332        True
# ...              ...         ...
# 473749    0000451965        True
# 473752    26-2261031        True
# 473754    45-5510883        True
# 473755    0000002551        True
# 473756    0000006694        True
#
# [88185 rows x 2 columns]

# %%
bigtest.to_csv('pred/testex2.csv', index=False)

# %%
bigtest2 = pd.read_csv('pred/test2.csv')

# %% [raw]
# check= pd.merge(bigtest,bigtest2,on='Respondent_ID')

# %% [raw]
# check.to_csv('pred/check.csv', index=False)

# %% [raw]
# check = pd.merge(bigtest, bigtest2,on='Respondent_ID', how = 'left', validate = 'm:1',indicator=True)
# check.to_csv('pred/check.csv', index=False)

# %%
#check.loc[check['Prediction_x'] != [check['Prediction_y']]]
